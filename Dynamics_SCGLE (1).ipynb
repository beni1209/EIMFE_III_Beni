# %% [markdown]
# # SCGLE Workshop
#
# by
#
# Jesús Benigno Zepeda López
#
# contact: benignoz@ifisica.uaslp.mx

# %% [markdown]
# # Outline
# - Jupyter Installation
# - LANIMFE's Julia repositories
# -- Approximation Grids
# -- Structural approximations
# -- Liquids Dynamics

# %% [markdown]
# # Jupyter Installation
#
# Requirements:
#
# - Julia
# - Internet Connection

# %% [markdown]
# Inside a Julia terminal press the key "]" to prompt the package environment
# ![01.png](attachment:01.png)

# %% [markdown]
# Write down the command "add IJulia" and press enter
# ![02.png](attachment:02.png)

# %% [markdown]
# If installation occured without any set back, a message similar to this should appear
# ![03-3.jpeg](attachment:03-3.jpeg)

# %% [markdown]
# Return to Julia environment by pressing the "backspace" key
#
# Load the IJulia package to the current Julia session by running "using IJulia" command
#
# Start Jupyter notebook by running the function "notebook()"
#
# The first time it is run, it will ask to install Jupyter via Conda, simply follow the instructions
#
# ![04-2.jpeg](attachment:04-2.jpeg)

# %% [markdown]
# If everything was installed correctly, a window in your main internet navigator will be open, or an app will ask for permission to be open with a navigator program, accept correspondingly. From here on, you can open/create notebooks (.ipynb files) similar to this.
# ![05.png](attachment:05.png)

# %% [markdown]
# # LANIMFE's Julia repositories

# %% [markdown]
# To download the repositories you can make use of the add environment and simply add the url of the wanted repository. Another way around this is to simply run the next cell:

# %% [markdown]
# ### Approximation Grids:
#     Implementation of several nodes and weights methods for integration purposes.
# ### Liquids Structure:
#     Implementation of different structure factors for different fluids.

# %% [markdown]
# ### Liquids Dynamics:
#     Implementation of numerical solution to SCGLE coupled set of equations.
# ### Liquids NEq Processes:
#     Implementation of numerical solution to NE-SCGLE equations. (Under construction)

# %%
using Pkg

# The next line only needs to be called once per Julia installation
pkg"registry add https://github.com/LANIMFE/LANIMFE-Registry"

pkg"activate ."
pkg"instantiate"
# Out:
#      Cloning registry from "https://github.com/LANIMFE/LANIMFE-Registry"
#        Added registry `LANIMFE` to `C:\Users\Beni\.julia\registries\LANIMFE`
#   Activating environment at `C:\Users\Beni\Desktop\trabajo\Project.toml`
#     Updating registry at `C:\Users\Beni\.julia\registries\General`
#     Updating registry at `C:\Users\Beni\.julia\registries\LANIMFE`
#     Updating git-repo `https://github.com/LANIMFE/LANIMFE-Registry`
# ┌ Warning: Some registries failed to update:
# │     — `C:\Users\Beni\.julia\registries\General` — registry dirty
# └ @ Pkg.Types C:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.6\Pkg\src\Types.jl:1246
#      Cloning [ee594226-bf90-11e9-0512-4d00cc65c9b3] LiquidsDynamics from https://github.com/LANIMFE/LiquidsDynamics.jl
#    Installed LiquidsDynamics ───── v0.1.1
#      Cloning [cb65a40a-bf8e-11e9-04fa-670b3879d50e] LiquidsNEqProcesses from https://github.com/LANIMFE/LiquidsNEqProcesses.jl
#    Installed LiquidsNEqProcesses ─ v0.1.1
#      Cloning [3b2fbd69-638f-58f2-a86a-379d5727c4f6] LiquidsStructure from https://github.com/LANIMFE/LiquidsStructure.jl
#    Installed LiquidsStructure ──── v0.1.1
#     Updating `C:\Users\Beni\Desktop\trabajo\Project.toml`
#   [4a901fcc] + ApproximationGrids v0.1.0
#   [7073ff75] + IJulia v1.23.2
#   [ee594226] + LiquidsDynamics v0.1.1
#   [cb65a40a] + LiquidsNEqProcesses v0.1.1
#   [3b2fbd69] + LiquidsStructure v0.1.1
#   [91a5bcdd] + Plots v1.21.1
#   [276daf66] + SpecialFunctions v1.6.1
#     Updating `C:\Users\Beni\Desktop\trabajo\Manifest.toml`
#   [621f4979] + AbstractFFTs v1.0.1
#   [79e6a3ab] + Adapt v3.3.1
#   [4a901fcc] + ApproximationGrids v0.1.0
#   [d360d2e6] + ChainRulesCore v1.3.0
#   [35d6a980] + ColorSchemes v3.14.0
#   [3da002f7] + ColorTypes v0.11.0
#   [5ae59095] + Colors v0.12.8
#   [34da2185] + Compat v3.34.0
#   [8f4d0f93] + Conda v1.5.2
#   [d38c429a] + Contour v0.5.7
#   [9a962f9c] + DataAPI v1.7.0
#   [864edb3b] + DataStructures v0.18.10
#   [e2d170a0] + DataValueInterfaces v1.0.0
#   [ffbed154] + DocStringExtensions v0.8.5
#   [c87230d0] + FFMPEG v0.4.1
#   [7a1cc6ca] + FFTW v1.4.3
#   [53c48c17] + FixedPointNumbers v0.8.4
#   [59287772] + Formatting v0.4.2
#   [28b8d3ca] + GR v0.58.1
#   [5c1252a2] + GeometryBasics v0.4.1
#   [42e2da0e] + Grisu v1.0.2
#   [cd3eb016] + HTTP v0.9.13
#   [7073ff75] + IJulia v1.23.2
#   [83e8ac13] + IniFile v0.5.0
#   [92d709cd] + IrrationalConstants v0.1.0
#   [c8e1da08] + IterTools v1.3.0
#   [82899510] + IteratorInterfaceExtensions v1.0.0
#   [692b3bcd] + JLLWrappers v1.3.0
#   [682c06a0] + JSON v0.21.2
#   [b964fa9f] + LaTeXStrings v1.2.1
#   [23fbe1c1] + Latexify v0.15.6
#   [ee594226] + LiquidsDynamics v0.1.1
#   [cb65a40a] + LiquidsNEqProcesses v0.1.1
#   [3b2fbd69] + LiquidsStructure v0.1.1
#   [2ab3a3ac] + LogExpFunctions v0.3.0
#   [1914dd2f] + MacroTools v0.5.7
#   [739be429] + MbedTLS v1.0.3
#   [442fdcdd] + Measures v0.3.1
#   [e1d29d7a] + Missings v1.0.1
#   [77ba4419] + NaNMath v0.3.5
#   [bac558e1] + OrderedCollections v1.4.1
#   [d96e819e] + Parameters v0.12.2
#   [69de0a69] + Parsers v2.0.3
#   [ccf2f8ad] + PlotThemes v2.0.1
#   [995b91a9] + PlotUtils v1.0.12
#   [91a5bcdd] + Plots v1.21.1
#   [21216c6a] + Preferences v1.2.2
#   [3cdcf5f2] + RecipesBase v1.1.2
#   [01d81517] + RecipesPipeline v0.3.5
#   [189a3867] + Reexport v1.2.2
#   [ae029012] + Requires v1.1.3
#   [6c6a2e73] + Scratch v1.1.0
#   [992d4aef] + Showoff v1.0.3
#   [b85f4697] + SoftGlobalScope v1.1.0
#   [a2af1166] + SortingAlgorithms v1.0.1
#   [276daf66] + SpecialFunctions v1.6.1
#   [90137ffa] + StaticArrays v1.2.12
#   [82ae8749] + StatsAPI v1.0.0
#   [2913bbd2] + StatsBase v0.33.9
#   [09ab397b] + StructArrays v0.6.1
#   [3783bdb8] + TableTraits v1.0.1
#   [bd369af6] + Tables v1.5.0
#   [5c2747f8] + URIs v1.3.0
#   [3a884ed6] + UnPack v1.0.2
#   [81def892] + VersionParsing v1.2.0
#   [c2297ded] + ZMQ v1.2.1
#   [6e34b625] + Bzip2_jll v1.0.6+5
#   [83423d85] + Cairo_jll v1.16.0+6
#   [5ae413db] + EarCut_jll v2.1.5+1
#   [2e619515] + Expat_jll v2.2.10+0
#   [b22a6f82] + FFMPEG_jll v4.3.1+4
#   [f5851436] + FFTW_jll v3.3.9+8
#   [a3f928ae] + Fontconfig_jll v2.13.1+14
#   [d7e528f0] + FreeType2_jll v2.10.1+5
#   [559328eb] + FriBidi_jll v1.0.10+0
#   [0656b61e] + GLFW_jll v3.3.5+0
#   [d2c73de3] + GR_jll v0.58.1+0
#   [78b55507] + Gettext_jll v0.21.0+0
#   [7746bdde] + Glib_jll v2.68.3+0
#   [1d5cc7b8] + IntelOpenMP_jll v2018.0.3+2
#   [aacddb02] + JpegTurbo_jll v2.1.0+0
#   [c1c5ebd0] + LAME_jll v3.100.1+0
#   [dd4b983a] + LZO_jll v2.10.1+0
#   [dd192d2f] + LibVPX_jll v1.10.0+0
#   [e9f186c6] + Libffi_jll v3.2.2+0
#   [d4300ac3] + Libgcrypt_jll v1.8.7+0
#   [7e76a0d4] + Libglvnd_jll v1.3.0+3
#   [7add5ba3] + Libgpg_error_jll v1.42.0+0
#   [94ce4f54] + Libiconv_jll v1.16.1+1
#   [4b2f31a3] + Libmount_jll v2.35.0+0
#   [89763e89] + Libtiff_jll v4.3.0+0
#   [38a345b3] + Libuuid_jll v2.36.0+0
#   [856f044c] + MKL_jll v2021.1.1+1
#   [e7412a2a] + Ogg_jll v1.3.5+0
#   [458c3c95] + OpenSSL_jll v1.1.10+0
#   [efe28fd5] + OpenSpecFun_jll v0.5.5+0
#   [91d4177d] + Opus_jll v1.3.2+0
#   [2f80f16e] + PCRE_jll v8.44.0+0
#   [30392449] + Pixman_jll v0.40.1+0
#   [ea2cea3b] + Qt5Base_jll v5.15.3+0
#   [a2964d1f] + Wayland_jll v1.19.0+0
#   [2381bf8a] + Wayland_protocols_jll v1.18.0+4
#   [02c8fc9c] + XML2_jll v2.9.12+0
#   [aed1982a] + XSLT_jll v1.1.34+0
#   [4f6342f7] + Xorg_libX11_jll v1.6.9+4
#   [0c0b7dd1] + Xorg_libXau_jll v1.0.9+4
#   [935fb764] + Xorg_libXcursor_jll v1.2.0+4
#   [a3789734] + Xorg_libXdmcp_jll v1.1.3+4
#   [1082639a] + Xorg_libXext_jll v1.3.4+4
#   [d091e8ba] + Xorg_libXfixes_jll v5.0.3+4
#   [a51aa0fd] + Xorg_libXi_jll v1.7.10+4
#   [d1454406] + Xorg_libXinerama_jll v1.1.4+4
#   [ec84b674] + Xorg_libXrandr_jll v1.5.2+4
#   [ea2f1a96] + Xorg_libXrender_jll v0.9.10+4
#   [14d82f49] + Xorg_libpthread_stubs_jll v0.1.0+3
#   [c7cfdc94] + Xorg_libxcb_jll v1.13.0+3
#   [cc61e674] + Xorg_libxkbfile_jll v1.1.0+4
#   [12413925] + Xorg_xcb_util_image_jll v0.4.0+1
#   [2def613f] + Xorg_xcb_util_jll v0.4.0+1
#   [975044d2] + Xorg_xcb_util_keysyms_jll v0.4.0+1
#   [0d47668e] + Xorg_xcb_util_renderutil_jll v0.3.9+1
#   [c22f9ab0] + Xorg_xcb_util_wm_jll v0.4.1+1
#   [35661453] + Xorg_xkbcomp_jll v1.4.2+4
#   [33bec58e] + Xorg_xkeyboard_config_jll v2.27.0+4
#   [c5fb5394] + Xorg_xtrans_jll v1.4.0+3
#   [8f1865be] + ZeroMQ_jll v4.3.4+0
#   [3161d3a3] + Zstd_jll v1.5.0+0
#   [0ac62f75] + libass_jll v0.14.0+4
#   [f638f0a6] + libfdk_aac_jll v0.1.6+4
#   [b53b4c65] + libpng_jll v1.6.38+0
#   [a9144af2] + libsodium_jll v1.0.20+0
#   [f27f6e37] + libvorbis_jll v1.3.7+0
#   [1270edf5] + x264_jll v2020.7.14+2
#   [dfaa095f] + x265_jll v3.0.0+3
#   [d8fb68d0] + xkbcommon_jll v0.9.1+5
#   [0dad84c5] + ArgTools
#   [56f22d72] + Artifacts
#   [2a0f44e3] + Base64
#   [ade2ca70] + Dates
#   [8bb1440f] + DelimitedFiles
#   [8ba89e20] + Distributed
#   [f43a241f] + Downloads
#   [7b1f6079] + FileWatching
#   [b77e0a4c] + InteractiveUtils
#   [4af54fe1] + LazyArtifacts
#   [b27032c2] + LibCURL
#   [76f85450] + LibGit2
#   [8f399da3] + Libdl
#   [37e2e46d] + LinearAlgebra
#   [56ddb016] + Logging
#   [d6f4376e] + Markdown
#   [a63ad114] + Mmap
#   [ca575930] + NetworkOptions
#   [44cfe95a] + Pkg
#   [de0858da] + Printf
#   [3fa0cd96] + REPL
#   [9a3f8284] + Random
#   [ea8e919c] + SHA
#   [9e88b42a] + Serialization
#   [1a1011a3] + SharedArrays
#   [6462fe0b] + Sockets
#   [2f01184e] + SparseArrays
#   [10745b16] + Statistics
#   [fa267f1f] + TOML
#   [a4e569a6] + Tar
#   [8dfed614] + Test
#   [cf7118a7] + UUIDs
#   [4ec0a83e] + Unicode
#   [e66e0078] + CompilerSupportLibraries_jll
#   [deac9b47] + LibCURL_jll
#   [29816b5a] + LibSSH2_jll
#   [c8ffd9c3] + MbedTLS_jll
#   [14a3606d] + MozillaCACerts_jll
#   [83775a58] + Zlib_jll
#   [8e850ede] + nghttp2_jll
#   [3f19e933] + p7zip_jll

# %% [markdown]
# ### Using the repositories
#     To use them simply load them to your current Julia session, as done in the next cell:

# %%
#Loading LANIMFE repositories:
using ApproximationGrids
using LiquidsNEqProcesses
using LiquidsDynamics
using LiquidsStructure

# Other useful packages
using SpecialFunctions
#Loading a Plotter:
using Plots
# Out:
# ┌ Info: Precompiling LiquidsNEqProcesses [cb65a40a-bf8e-11e9-04fa-670b3879d50e]
# └ @ Base loading.jl:1423

# %% [markdown]
# # Approximation Grids

# %% [markdown]
# $\int _{x_0}^{x_1} f(x) dx \approx \sum _{i=0}^n f(x_i) w_i$

# %% [markdown]
# ### Newton-Cotes polynomials quadratures
#
# Order 1:
# - Rectangles
#
# $\int_{x_0}^{x_1}f(x_i)dx\approx \frac{x_1-x_0}{2} \times f(0.5x_1+0.5x_0)$
#
# $w_i=\frac{x_1-x_{0}}{2}; x_i=(x_1+x_0)/2$
#
# - Trapezoids

# %% [markdown]
# Order 2:
#
# - Simpson 3/4
#
# $\int_{x_0}^{x_1}f(x_i)dx\approx \frac{x_1-x_0}{6} \times [ f(x_1) + 4f(0.5x_1+0.5x_0)  + f(x_0)  ]$
#
# $w_0=w_2=w_1/4=\frac{x_1-x_0}{6}; x_i=x_0 + i(x_1-x_0)/2$

# %% [markdown]
# ### Clenshaw-Curtis quadrature

# %% [markdown]
# $\int_{-1}^{1}f(x)dx=\int_0^{\pi}f(\cos\theta)\sin\theta d\theta=a_0+\sum_{i=1}^{\infty}\frac{2a_{2k}\cos (k\theta)}{1-(2k)^2}$
#
# $f(\cos\theta)=\frac{a_0}{2}+\sum_{k=1}^{\infty}a_k\cos (k\theta)$

# %% [markdown]
# ### Clenshaw-Curtis quadrature

# %% [markdown]
# $a_k=\frac{2}{\pi}\int_0^{\pi}f(\cos\theta)\cos(k\theta)d\theta$
#
# for $\theta_n=n\pi/N$
#
# $a_k\approx\frac{2}{N}\left[ \frac{f(1)+(-1)^kf(-1)}{2} + \sum_{n=1}^{N-1}f(\cos[n\pi/N])\cos(nk\pi/N)\right]$

# %% [markdown]
# ### Making use of Approximation Grids

# %%
#Inferior Limit
x₀=0
#Superior Limit
x₁=9
#Number of points
np=2^7
## Calling chevishev method with the corresponding limits and number of points
CC=ChebyshevGrid(x₀, x₁, np)
## Calling a Newton-Cotes implementation with the corresponding limits and number of points
NC=RegularGrid(x₀, x₁, np)
# Out:
# RegularGrid((0.0,9.0), 128)

# %%
println("Nodes:\n\n",nodes(CC))
println("\n Weights: \n\n",ApproximationGrids.weights(CC))
println("\n Jacobian: \n\n",jacobian(CC),"\n\n")
# Out:
# Nodes:
#
# [0.0003388417238499031, 0.0030492693524273307, 0.008468491949328971, 0.01659324517749905, 0.027418634989397894, 0.04093814057498957, 0.05714361828963721, 0.07602530655952666, 0.09757183176167583, 0.12177021507497887, 0.1486058802981658, 0.17806266262995418, 0.2101228184061279, 0.24476703578765413, 0.28197444639341285, 0.32172263787053, 0.3639876673947402, 0.40874407609264907, 0.4559649043772076, 0.5056217081871575, 0.5576845761206704, 0.61212214745286, 0.6689016310263067, 0.7279888250032287, 0.7893481374673863, 0.8529426078633238, 0.9187339292600241, 0.9866824714255746, 1.0567473046989346, 1.128886224644433, 1.2030557774741424, 1.2792112862228158, 1.3573068776596222, 1.4372955099204612, 1.5191290008442269, 1.6027580569959383, 1.6881323033592617, 1.7752003136805352, 1.8639096414460252, 1.9542068514737405, 2.046037552100791, 2.1393464279468897, 2.234077273234271, 2.3301730256439477, 2.42757580068792, 2.5262269265766255, 2.6260669795606324, 2.7270358197252835, 2.829072627216731, 2.932115938877544, 3.0361036852698167, 3.1409732280634737, 3.246661397767261, 3.3531045317796844, 3.46023851273698, 3.5679988071350164, 3.6763205042018656, 3.7851383549976236, 3.894386811717932, 4.004000067177526, 4.11391209445002, 4.224056686640061, 4.334367496763885, 4.44477807771426, 4.55522192228574, 4.665632503236115, 4.775943313359939, 4.88608790554998, 4.995999932822474, 5.105613188282068, 5.214861645002377, 5.323679495798134, 5.432001192864983, 5.53976148726302, 5.646895468220316, 5.7533386022327395, 5.859026771936526, 5.963896314730183, 6.067884061122456, 6.170927372783269, 6.272964180274716, 6.373933020439368, 6.4737730734233745, 6.5724241993120796, 6.669826974356052, 6.765922726765729, 6.86065357205311, 6.953962447899209, 7.0457931485262595, 7.136090358553975, 7.224799686319464, 7.311867696640738, 7.397241943004062, 7.480870999155773, 7.562704490079539, 7.642693122340377, 7.720788713777184, 7.796944222525857, 7.8711137753555676, 7.943252695301066, 8.013317528574426, 8.081266070739975, 8.147057392136677, 8.210651862532615, 8.272011174996772, 8.331098368973693, 8.38787785254714, 8.442315423879329, 8.494378291812843, 8.544035095622792, 8.591255923907351, 8.63601233260526, 8.67827736212947, 8.718025553606587, 8.755232964212347, 8.789877181593873, 8.821937337370045, 8.851394119701833, 8.878229784925022, 8.902428168238323, 8.923974693440474, 8.942856381710364, 8.95906185942501, 8.972581365010601, 8.9834067548225, 8.99153150805067, 8.996950730647573, 8.999661158276151]
#
#  Weights:
#
# [0.0002628357072017723, 0.0009249899991174079, 0.0014907082231271108, 0.002116377084453454, 0.0026968973332133737, 0.0033099961794389584, 0.0038931202610793395, 0.004497543115602177, 0.0050788103192167325, 0.005675008203170062, 0.006251745925284662, 0.006839175137555958, 0.007409342588579314, 0.007987078618153272, 0.008548922859893124, 0.009115873663669654, 0.00966779984202341, 0.010222796978394125, 0.010763311740373805, 0.011305155615923684, 0.01183284018059979, 0.0123603253695222, 0.012873822157847051, 0.013385753079530308, 0.013883759122377269, 0.014378960637332835, 0.014860224606135418, 0.015337549735295141, 0.015800871006014277, 0.016259206915553024, 0.016703435812062465, 0.01714170868914759, 0.01756574742154081, 0.01798292659931434, 0.018385730608993216, 0.018780832153794252, 0.019161411686704946, 0.019533501578004774, 0.019890923371049318, 0.020239120355929775, 0.02057250935997672, 0.020895987534400362, 0.021204528621251904, 0.021502519771895698, 0.02178545938794848, 0.022057255116573648, 0.022313902856082212, 0.022558856500740885, 0.02278858657851002, 0.023006114940834203, 0.02320836754900399, 0.02339795243346296, 0.02357223497053091, 0.023733424539305107, 0.023879312702110436, 0.02401172264774596, 0.024128861379113985, 0.02423217591615353, 0.024320280202458362, 0.02439425287863096, 0.024453108392809484, 0.024497562719995685, 0.0245270263066255, 0.024541856211618834, 0.024541856211618834, 0.0245270263066255, 0.024497562719995685, 0.024453108392809484, 0.02439425287863096, 0.024320280202458362, 0.02423217591615353, 0.024128861379113985, 0.02401172264774596, 0.023879312702110436, 0.023733424539305107, 0.02357223497053091, 0.02339795243346296, 0.02320836754900399, 0.023006114940834203, 0.02278858657851002, 0.022558856500740885, 0.022313902856082212, 0.022057255116573648, 0.02178545938794848, 0.021502519771895698, 0.021204528621251904, 0.020895987534400362, 0.02057250935997672, 0.020239120355929775, 0.019890923371049318, 0.019533501578004774, 0.019161411686704946, 0.018780832153794252, 0.018385730608993216, 0.01798292659931434, 0.01756574742154081, 0.01714170868914759, 0.016703435812062465, 0.016259206915553024, 0.015800871006014277, 0.015337549735295141, 0.014860224606135418, 0.014378960637332835, 0.013883759122377269, 0.013385753079530308, 0.012873822157847051, 0.0123603253695222, 0.01183284018059979, 0.011305155615923684, 0.010763311740373805, 0.010222796978394125, 0.00966779984202341, 0.009115873663669654, 0.008548922859893124, 0.007987078618153272, 0.007409342588579314, 0.006839175137555958, 0.006251745925284662, 0.005675008203170062, 0.0050788103192167325, 0.004497543115602177, 0.0038931202610793395, 0.0033099961794389584, 0.0026968973332133737, 0.002116377084453454, 0.0014907082231271108, 0.0009249899991174079, 0.0002628357072017723]
#
#  Jacobian:
#
# 4.5

# %%
println("Nodes:\n\n",nodes(NC))
println("\n","Weights:","\n\n",ApproximationGrids.weights(NC))
println("\n Jacobian: \n\n",jacobian(NC),"\n\n\n")
# Out:
# Nodes:
#
# 0.0:0.07086614173228346:9.0
#
# Weights:
#
# [0.375, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.125, 1.125, 0.75, 1.1666666666666667, 0.9166666666666666, 1.1666666666666667, 0.375]
#
#  Jacobian:
#
# 0.07086614173228346

# %% [markdown]
# ### Integration test

# %%
f(x)=exp(-x^2)
x₀=0
x₁=100
np=100

CC=ChebyshevGrid(x₀, x₁, np)
NC=RegularGrid(x₀, x₁, np)
∫CCdx=sum(f.(nodes(CC)).*ApproximationGrids.weights(CC))*jacobian(CC)
∫NCdx=sum(f.(nodes(NC)).*ApproximationGrids.weights(NC))*jacobian(NC)

println("√π / 2 * erf(100): \n", √π / 2 * erf(100), "\n")
println("Clenshaw Curtis: \n", ∫CCdx, "\n")
println("Newton-Cotes: \n", ∫NCdx, "\n")
# Out:
# √π / 2 * erf(100):
# 0.8862269254527579
#
# Clenshaw Curtis:
# 0.886226922782908
#
# Newton-Cotes:
# 0.8076979320508492

# %% [markdown]
# # Liquids Structure
#
# Principal outputs:
#
# $u(r) + (N,V,T) + \mathcal{F}_{approx} \to S(k)$

# %% [markdown]
# ## Hard core fluid and structure factor
#
# ### Interaction Potential
#
# $u(r)=\begin{cases}
#         \infty,~~~~~~~~~~~ r<\sigma\\
#         0, ~~~~~~~~~~~~~   r \geq \sigma
# \end{cases}$

# %%
function circleShape(h,k,r)
    θ=LinRange(0,2π,200)
    return h .+ r*sin.(θ), k.+r*cos.(θ)
end
# Out:
# circleShape (generic function with 1 method)

# %%
u(r,σ)= r < σ ? 1/0 : 0
r=range(0,4,length=100)
σ=1
contact=σ*range(1,1,length=100),range(0,10,length=100)
plot(r,u.(r,σ),ylims=[-1.5,1.5],label="u(r)",xlabel="r/σ",ylabel="u(r)")
plot!(contact,label=false,linecolor=1)
plot!(circleShape(0,0,0.5σ),seriestype=[:shape],fillalpha=0.1,label="Particle 1")
plot!(circleShape(σ,0,0.5σ),seriestype=[:shape],fillalpha=0.1,label="Particle 2")

# %% [markdown]
# # Hard core fluid and structure factor
#
# ### Thermodynamic Parameters
# 3D -> $\phi=\pi \rho\sigma^3/6$;
#
# 2D -> $\phi=\pi \rho\sigma^2/4$

# %% [markdown]
# ### Sphere Approximations
#
# - Percus-Yevick
# - Verlet-Weiss correction
#
# ### Disk Approximation
#
# - Fundamental Measure Theory

# %% [markdown]
# # Example

# %%
ϕ=0.58 #Volume fraction
liquid_HS = HardSpheres(ϕ); liquid_HD = HardDisks(ϕ) #Liquids definition
S_HS_VW = StructureFactor(liquid_HS, VerletWeis) #S(k) definition
S_HS_PY = StructureFactor(liquid_HS, PercusYevick)#S(k) definition
S_HD = StructureFactor(liquid_HD, RosenfeldFMT)# S(k) definition
plot(k -> S_HS_VW(k), 0, 13π, label = "3D-VW; ϕ="*string(ϕ),xlabel="kσ",ylabel="S(k)")
plot!(k -> S_HS_PY(k), 0, 13π, label = "3D-PY; ϕ="*string(ϕ))
plot!(k -> S_HD(k), 0, 13π, label = "2D-FMT; ϕ="*string(ϕ))

# %% [markdown]
# ### Composite potentials
#
# Hard Sphere + Attractive Yukawa
#
#
# $u(r)=\begin{cases}
#         \infty,~~~~~~~~~~~~~~~~~~~~~~~~~~~~ r\leq\sigma\\
#         -\frac{\sigma \epsilon}{r} e^{-z(r/\sigma-1)},~~~~~~~~~~~ r> \sigma
# \end{cases}$
#
# Hard Sphere + Square Well
#
#
# $u(r)=\begin{cases}
#         \infty,~~~~~~~~~~~ r\leq\sigma\\
#         -\epsilon,~~~~~~~~~~~ \sigma <r\geq \lambda \sigma\\
#         0, ~~~~~~~~~~~~~   r \geq \lambda \sigma
# \end{cases}$

# %%
r=range(0,4,length=1000)
σ=1;λ=1.5;z=2
uHSSW(r,σ)= r < σ ? 1/0 : r < λ*σ ? -1 : 0
uHSAY(r,σ)= r < σ ? 1/0 : -exp(-z*(r-1))/r
contact=σ*range(1,1,length=100),range(-1,10,length=100)
plot(r,uHSSW.(r,σ),ylims=[-1.5,1.5],label="HSSW",xlabel="r/σ",ylabel="u/ϵ")
plot!(contact,label=false,linecolor=3)
plot!(r,uHSAY.(r,σ),ylims=[-1.5,1.5],label="HSAY",xlabel="r/σ",ylabel="u/ϵ")
plot!(circleShape(0,0,0.5σ),seriestype=[:shape],fillalpha=0.1,label="Particle 1")
plot!(circleShape(1.5σ,0,0.5σ),seriestype=[:shape],fillalpha=0.1,label="Particle 2")
plot!([0,0.6],[0.6,0.6],arrow=true,color=:black,linewidth=2,label="")
plot!([1.5,0.8],[0.6,0.6],arrow=true,color=:black,linewidth=2,label="")

# %% [markdown]
# ### Potential and Thermodynamic Parameters
#
# $(\phi=\pi \rho\sigma^3/6$;$T^*=k_BT/\epsilon )$
#
# ### Range of attraction parameters
# $\lambda$; $z$

# %% [markdown]
# ### Approximations
# - Mean Field Theory
#
# $c(r) \approx c_{HC}(r) - \beta u_a(r)$
#
# - Modified Mean Field theory
#
# $c(r) \approx c_{HC}(r) + \left[ exp(-\beta u_a(r))-1 \right]$
#
# $S(k)=\frac{1}{1-\rho \hat{c}(k)}$

# %% [markdown]
# # Examples

# %%
z=2.0; λ=1.5 ; T = 1.8; ϕ=0.3;
urHSAY = Yukawa{3}(z); urHSSW = SquareWell{3}(λ)
liquid_HSAY = AttractiveHardSpheres(ϕ,T,urHSAY)
liquid_HSSW = AttractiveHardSpheres(ϕ,T,urHSSW)
S_HSSW = StructureFactor(liquid_HSSW, NonLinearSharmaSharma{VerletWeis})
S_HSAY = StructureFactor(liquid_HSAY, SharmaSharma{VerletWeis})
plot(k -> S_HSAY(k), 0, 13π, label = "MF-HSAY; ϕ="*string(ϕ)*"; T="*string(T),xlabel="kσ", ylabel="S(k)");plot!(k -> S_HSSW(k), 0, 13π, label = "MMF-HSSW; ϕ="*string(ϕ)*"; T="*string(T))

# %% [markdown]
# # Liquids Dynamics
#
# ### Principal outputs
#
# - Intermediate Scattering Function (ISF) $F(k,\tau)$
# - Self part of the ISF $F_s(k,\tau)$
# - Memory kernel or correlation time dependent friction $\Delta\zeta(\tau)$
# - Mobility or long time dependent diffusion coefficient $D^*_L$

# %% [markdown]
# ### Solution to SCGLE set of equations
#
# $\hat{F}_s(k,z) =\frac{1}{z+\frac{k^2D_0}{1+\lambda(k)\Delta \zeta(z)}}$; $\hat{F}(k,z)=\frac{S(k)}{z+\frac{k^2D_0 S^{-1}(k)}{1+\lambda(k)\Delta \zeta(z)}}$
#
# $\Delta\zeta^*(\tau)=\frac{D_0}{24\pi^3\bar{n}}\int _V k^2\Bigg[ \frac{S(k)-1}{S(k)} \Bigg]^2 F(k,\tau) F_s(k,\tau) d\mathbf{k}$

# %%
λ=1.5 ; T = 1.8; ϕ=0.35; urHSSW = SquareWell{3}(λ)
liquid_HSSW = AttractiveHardSpheres(ϕ,T,urHSSW); S_HSSW = StructureFactor(liquid_HSSW, NonLinearSharmaSharma{VerletWeis})
k₀ = 0; k₁ = 40; kₛ = ChebyshevGrid(k₀, k₁, 4064); #Grid creation
S₀ = StructureFactorGrid(S_HSSW,kₛ) #Setting the grid for the structure factor
dyn_var = dynamics(S₀, 2π); #Solving dynamics

# %%
τ  = dyn_var.τ
Fs = dyn_var.dvars.Fˢ
Fc = dyn_var.dvars.F
Δζ = dyn_var.dvars.ζ
Dl = dyn_var.b
# Out:
# (0.0032379946716030055)

# %%
plot(τ,Fs,xaxis= :log10, label="SCGLE, HSSW, ϕ="*string(ϕ)*"; T*="*string(T), xlabel="τ", ylabel="Fₛ(k=2π,τ)")
plot!(τ,exp.(-4π^2*τ), label="Fs≈exp(-k²D₀τ)")

# %% [markdown]
# # Asymptotic solutions to SCGLE equations
#
# $\lim_{\tau \to \infty} \Delta \zeta (\tau)=\Delta \zeta ^{\infty}$
#
# $\lim_{\tau \to \infty} F(k,\tau)= f(k)$
#
# $\lim_{\tau \to \infty} F_s(k,\tau)=f_s(k)$

# %% [markdown]
# # Asymptotic solutions to SCGLE equations
#
# $\gamma\equiv D_0/ \Delta \zeta ^{\infty}$
#
# $\gamma^{-1}=\frac{1}{3 (2\pi)^3 \bar{n}}\int d\mathbf{k}\frac{k^2+[S(k)-1]^2\lambda^2(k)}{[\lambda(k)S(k)+k^2\gamma][\lambda(k)+k^2\gamma]}$

# %% [markdown]
# ### Solution to asymptotic equations

# %%
asymp   = asymptotics(S₀);  #Solving asymptotics
fs  = asymp.fˢ
fc  = asymp.f
Δζ∞ = asymp.ζ∞;

# %% [markdown]
# ### Other non-implemented outputs
#
# - $\alpha$-relaxation time $\tau_\alpha$
# - Mean squared displacement $<(\Delta r)^2 >$
# - Viscosity $\eta$
# - Visco-elastic modulus $G'(\omega)$; $G''(\omega)$

# %% [markdown]
# # Acknowledgements
#
# - CONACyT grants LANIMFE
# - Pablo Fernando Zubieta Rico
# - Ernesto Carlos Cortes Morales

# %% [markdown]
# # Excercises
#
# - Make a function to compute $g(r)$ for any given $S(k)$
# - Make a function to find $S(k;\phi,T)=cte.$ and trace for Verlet crystallization criterion
# - Make a function to compute $\tau_\alpha$ from the dynamics $F_s$
# - Make a function to compute $\gamma$ and to compare with asymp
